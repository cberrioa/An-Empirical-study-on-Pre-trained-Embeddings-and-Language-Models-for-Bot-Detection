# %%
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.layers import Embedding, Input, Conv1D, MaxPooling1D, Flatten, Dense, Dropout, LSTM, Concatenate, Bidirectional
from keras.models import Model, Sequential
from keras.metrics import categorical_accuracy
from keras.metrics import binary_accuracy
from keras.utils import to_categorical
from keras.optimizers import Adam
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.metrics import classification_report, f1_score, precision_score, recall_score, accuracy_score
from sklearn.model_selection import KFold
import numpy as np
import json
import pandas as pd
import h5py
# Out:
# Using TensorFlow backend.

# %%
texts = []
texts_valid = []
labels_index = {}
labels = []
labels_valid = []
word_index = {}
mlb = MultiLabelBinarizer()
max_nb_words = 20000 # vocabulary size
#h5path = '/media/ssd/mydataset.hdf5'
h5path = '/media/ssd/mydataset-preprocessed.hdf5'
embedding_size = 1024
kfold = KFold(n_splits=10, shuffle=True)
max_sequence_length = 50

# %%
dataset_file="../data/train-preprocessed.tsv"
#dataset_file="../data/train.tsv"
dataset_sample= pd.read_csv(dataset_file,sep='\t',header=None,names=['user','label','none','text'],usecols=['label','text'])

# %%
#Prepare training data
for indx, doc in dataset_sample.iterrows():
  fields = [doc["label"]]
  label_ids = set()
  for field in fields:
      # Check if the field is already stored and if not, assign a new label to it.
      if field not in labels_index:
          label_id = len(labels_index)
          labels_index[field] = label_id
      else:
          label_id = labels_index[field]
      # Add the corresponding field label
      label_ids.add(label_id)
  texts.append(doc["text"])
  labels.append(label_ids)

# %%
# Tokenize the sentences of all the articles
tokenizer = Tokenizer(num_words=max_nb_words)
tokenizer.fit_on_texts(texts)
sequences = tokenizer.texts_to_sequences(texts)

# Get the vocabulary index
# word_index = tokenizer.word_index
word_index = { w:c for (w,c) in tokenizer.word_index.items() if c < max_nb_words}
print("Found %s unique tokens." % len(word_index))

# Fit the sequences into the maximum length
data = pad_sequences(sequences, maxlen=max_sequence_length, padding="post", truncating="post")
print("Shape of data tensor:", data.shape)
# Transform the labels into a binary vector, with one element for each category
labels_cat = mlb.fit_transform(labels)

print("Shape of label tensor:", labels_cat.shape)
# Out:
# Found 19999 unique tokens.
# Shape of data tensor: (500000, 50)
# Shape of label tensor: (500000, 2)

# %% [markdown]
# # Embeddings

# %% [markdown]
# ## ELMO

# %%
def gen_elmo_tweets_embeddings (h5path, indices,batchSize, shuffle,data):  
  db = h5py.File(h5path, "r")
  while True:
    if shuffle:
        np.random.shuffle(indices)
    for i in range(0, len(indices), batchSize):
        batch_indices = indices[i:i+batchSize]
        batch_indices.sort()
        
        bx = db['mydataset'][batch_indices,:max_sequence_length,:]
        by = db["labels"][batch_indices,:]

        yield ([bx,data[batch_indices]], by)

# %% [markdown]
# # BiLSTM

# %% [markdown]
# ## Random + ELMO

# %%
import time
precisions = []
recalls = []
f1s = []
times = []
datasize = 500000
batchSize=100
for train, test in kfold.split(data, labels_cat):
  # Define, train and validate the neural network model
  embedded_sequences = Input(shape=(max_sequence_length,embedding_size,), dtype="float32")
    
  sequence_input = Input(shape=(max_sequence_length,), dtype="int32")
  modelRandom = Embedding(len(word_index)+1, 300, embeddings_initializer="normal", input_length=max_sequence_length, trainable=True)(sequence_input)     
  
  modelMergeEmbeddings = Concatenate()([modelRandom, embedded_sequences])

  x = Bidirectional(LSTM(50))(modelMergeEmbeddings)
    
  preds = Dense(len(labels_index), activation="softmax")(x)
  
  model = Model([embedded_sequences, sequence_input], preds)
  model.compile(loss="binary_crossentropy", optimizer="adam", metrics=[categorical_accuracy])
  print (model.summary())

  t0 = time.time()
  model.fit_generator(gen_elmo_tweets_embeddings (h5path,train,batchSize=batchSize,shuffle=True,data=data), 
                        validation_data=gen_elmo_tweets_embeddings(h5path, test, batchSize=batchSize,shuffle=False,data=data), 
                        steps_per_epoch = len(train)//batchSize,  
                        validation_steps = len(test)//batchSize, 
                        epochs=5)
  t1 = time.time()
  times.append(t1-t0)

  # Evaluate the model assigning zeros and ones according to a threshold
  pred = pred = model.predict_generator(gen_elmo_tweets_embeddings(h5path, test, batchSize=batchSize,shuffle=False,data=data),steps = len(test)//batchSize)
  pred[pred >= 0.5] = 1
  pred[pred < 0.5] = 0
  print(classification_report(labels_cat[test], pred))
  precisions.append(precision_score(labels_cat[test], pred, average="weighted"))
  recalls.append(recall_score(labels_cat[test], pred, average="weighted"))
  f1s.append(f1_score(labels_cat[test], pred, average="weighted"))
print("Precision: %.4f (+/- %.4f)" % (np.mean(precisions), np.std(precisions)))
print("Recall: %.4f (+/- %.4f)" % (np.mean(recalls), np.std(recalls)))
print("F1 Score: %.4f (+/- %.4f)" % (np.mean(f1s), np.std(f1s)))
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_58 (InputLayer)           (None, 50)           0
# __________________________________________________________________________________________________
# embedding_39 (Embedding)        (None, 50, 300)      6000000     input_58[0][0]
# __________________________________________________________________________________________________
# input_57 (InputLayer)           (None, 50, 1024)     0
# __________________________________________________________________________________________________
# concatenate_29 (Concatenate)    (None, 50, 1324)     0           embedding_39[0][0]
#                                                                  input_57[0][0]
# __________________________________________________________________________________________________
# bidirectional_13 (Bidirectional (None, 100)          550000      concatenate_29[0][0]
# __________________________________________________________________________________________________
# dense_45 (Dense)                (None, 2)            202         bidirectional_13[0][0]
# ==================================================================================================
# Total params: 6,550,202
# Trainable params: 6,550,202
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# Epoch 1/5
# 4500/4500 [==============================] - 753s 167ms/step - loss: 0.4643 - categorical_accuracy: 0.7764 - val_loss: 0.4242 - val_categorical_accuracy: 0.7990
# Epoch 2/5
# 4500/4500 [==============================] - 783s 174ms/step - loss: 0.3959 - categorical_accuracy: 0.8169 - val_loss: 0.4129 - val_categorical_accuracy: 0.8091
# Epoch 3/5
# 4500/4500 [==============================] - 771s 171ms/step - loss: 0.3625 - categorical_accuracy: 0.8356 - val_loss: 0.4101 - val_categorical_accuracy: 0.8116
# Epoch 4/5
# 4500/4500 [==============================] - 784s 174ms/step - loss: 0.3315 - categorical_accuracy: 0.8522 - val_loss: 0.4180 - val_categorical_accuracy: 0.8130
# Epoch 5/5
# 4500/4500 [==============================] - 790s 176ms/step - loss: 0.3035 - categorical_accuracy: 0.8671 - val_loss: 0.4370 - val_categorical_accuracy: 0.8093
#               precision    recall  f1-score   support
#
#            0       0.81      0.74      0.77     21913
#            1       0.81      0.86      0.84     28087
#
#    micro avg       0.81      0.81      0.81     50000
#    macro avg       0.81      0.80      0.80     50000
# weighted avg       0.81      0.81      0.81     50000
#  samples avg       0.81      0.81      0.81     50000
#
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_60 (InputLayer)           (None, 50)           0
# __________________________________________________________________________________________________
# embedding_40 (Embedding)        (None, 50, 300)      6000000     input_60[0][0]
# __________________________________________________________________________________________________
# input_59 (InputLayer)           (None, 50, 1024)     0
# __________________________________________________________________________________________________
# concatenate_30 (Concatenate)    (None, 50, 1324)     0           embedding_40[0][0]
#                                                                  input_59[0][0]
# __________________________________________________________________________________________________
# bidirectional_14 (Bidirectional (None, 100)          550000      concatenate_30[0][0]
# __________________________________________________________________________________________________
# dense_46 (Dense)                (None, 2)            202         bidirectional_14[0][0]
# ==================================================================================================
# Total params: 6,550,202
# Trainable params: 6,550,202
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# Epoch 1/5
# 4500/4500 [==============================] - 824s 183ms/step - loss: 0.4634 - categorical_accuracy: 0.7765 - val_loss: 0.4240 - val_categorical_accuracy: 0.8030
# Epoch 2/5
# 4500/4500 [==============================] - 780s 173ms/step - loss: 0.3950 - categorical_accuracy: 0.8175 - val_loss: 0.4105 - val_categorical_accuracy: 0.8089
# Epoch 3/5
# 4500/4500 [==============================] - 797s 177ms/step - loss: 0.3626 - categorical_accuracy: 0.8351 - val_loss: 0.4134 - val_categorical_accuracy: 0.8086
# Epoch 4/5
# 4500/4500 [==============================] - 775s 172ms/step - loss: 0.3334 - categorical_accuracy: 0.8515 - val_loss: 0.4206 - val_categorical_accuracy: 0.8085
# Epoch 5/5
# 4500/4500 [==============================] - 776s 173ms/step - loss: 0.3049 - categorical_accuracy: 0.8662 - val_loss: 0.4363 - val_categorical_accuracy: 0.8092
#               precision    recall  f1-score   support
#
#            0       0.81      0.75      0.78     22195
#            1       0.81      0.86      0.83     27805
#
#    micro avg       0.81      0.81      0.81     50000
#    macro avg       0.81      0.80      0.81     50000
# weighted avg       0.81      0.81      0.81     50000
#  samples avg       0.81      0.81      0.81     50000
#
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_62 (InputLayer)           (None, 50)           0
# __________________________________________________________________________________________________
# embedding_41 (Embedding)        (None, 50, 300)      6000000     input_62[0][0]
# __________________________________________________________________________________________________
# input_61 (InputLayer)           (None, 50, 1024)     0
# __________________________________________________________________________________________________
# concatenate_31 (Concatenate)    (None, 50, 1324)     0           embedding_41[0][0]
#                                                                  input_61[0][0]
# __________________________________________________________________________________________________
# bidirectional_15 (Bidirectional (None, 100)          550000      concatenate_31[0][0]
# __________________________________________________________________________________________________
# dense_47 (Dense)                (None, 2)            202         bidirectional_15[0][0]
# ==================================================================================================
# Total params: 6,550,202
# Trainable params: 6,550,202
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# Epoch 1/5
# 4500/4500 [==============================] - 723s 161ms/step - loss: 0.4655 - categorical_accuracy: 0.7741 - val_loss: 0.4233 - val_categorical_accuracy: 0.8006
# Epoch 2/5
# 4500/4500 [==============================] - 825s 183ms/step - loss: 0.3956 - categorical_accuracy: 0.8161 - val_loss: 0.4169 - val_categorical_accuracy: 0.8056
# Epoch 3/5
# 4500/4500 [==============================] - 766s 170ms/step - loss: 0.3631 - categorical_accuracy: 0.8346 - val_loss: 0.4144 - val_categorical_accuracy: 0.8106
# Epoch 4/5
# 4500/4500 [==============================] - 756s 168ms/step - loss: 0.3336 - categorical_accuracy: 0.8505 - val_loss: 0.4214 - val_categorical_accuracy: 0.8079
# Epoch 5/5
# 4500/4500 [==============================] - 745s 166ms/step - loss: 0.3037 - categorical_accuracy: 0.8664 - val_loss: 0.4294 - val_categorical_accuracy: 0.8085
#               precision    recall  f1-score   support
#
#            0       0.83      0.72      0.77     22013
#            1       0.80      0.88      0.84     27987
#
#    micro avg       0.81      0.81      0.81     50000
#    macro avg       0.81      0.80      0.80     50000
# weighted avg       0.81      0.81      0.81     50000
#  samples avg       0.81      0.81      0.81     50000
#
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_64 (InputLayer)           (None, 50)           0
# __________________________________________________________________________________________________
# embedding_42 (Embedding)        (None, 50, 300)      6000000     input_64[0][0]
# __________________________________________________________________________________________________
# input_63 (InputLayer)           (None, 50, 1024)     0
# __________________________________________________________________________________________________
# concatenate_32 (Concatenate)    (None, 50, 1324)     0           embedding_42[0][0]
#                                                                  input_63[0][0]
# __________________________________________________________________________________________________
# bidirectional_16 (Bidirectional (None, 100)          550000      concatenate_32[0][0]
# __________________________________________________________________________________________________
# dense_48 (Dense)                (None, 2)            202         bidirectional_16[0][0]
# ==================================================================================================
# Total params: 6,550,202
# Trainable params: 6,550,202
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# Epoch 1/5
# 4500/4500 [==============================] - 777s 173ms/step - loss: 0.4630 - categorical_accuracy: 0.7761 - val_loss: 0.4218 - val_categorical_accuracy: 0.8024
# Epoch 2/5
# 4500/4500 [==============================] - 784s 174ms/step - loss: 0.3941 - categorical_accuracy: 0.8179 - val_loss: 0.4124 - val_categorical_accuracy: 0.8078
# Epoch 3/5
# 4500/4500 [==============================] - 794s 176ms/step - loss: 0.3605 - categorical_accuracy: 0.8366 - val_loss: 0.4106 - val_categorical_accuracy: 0.8089
# Epoch 4/5
# 4500/4500 [==============================] - 796s 177ms/step - loss: 0.3623 - categorical_accuracy: 0.8359 - val_loss: 0.4207 - val_categorical_accuracy: 0.8066
# Epoch 4/5
# 4500/4500 [==============================] - 791s 176ms/step - loss: 0.3034 - categorical_accuracy: 0.8677 - val_loss: 0.4368 - val_categorical_accuracy: 0.8060
#               precision    recall  f1-score   support
#
#            0       0.81      0.73      0.77     21974
#            1       0.80      0.86      0.83     28026
#
#    micro avg       0.81      0.81      0.81     50000
#    macro avg       0.81      0.80      0.80     50000
# weighted avg       0.81      0.81      0.80     50000
#  samples avg       0.81      0.81      0.81     50000
#
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_70 (InputLayer)           (None, 50)           0
# __________________________________________________________________________________________________
# embedding_45 (Embedding)        (None, 50, 300)      6000000     input_70[0][0]
# __________________________________________________________________________________________________
# input_69 (InputLayer)           (None, 50, 1024)     0
# __________________________________________________________________________________________________
# concatenate_35 (Concatenate)    (None, 50, 1324)     0           embedding_45[0][0]
#                                                                  input_69[0][0]
# __________________________________________________________________________________________________
# bidirectional_19 (Bidirectional (None, 100)          550000      concatenate_35[0][0]
# __________________________________________________________________________________________________
# dense_51 (Dense)                (None, 2)            202         bidirectional_19[0][0]
# ==================================================================================================
# Total params: 6,550,202
# Trainable params: 6,550,202
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# Epoch 1/5
# 4500/4500 [==============================] - 776s 172ms/step - loss: 0.3619 - categorical_accuracy: 0.8363 - val_loss: 0.4154 - val_categorical_accuracy: 0.8062
# Epoch 4/5
# 4500/4500 [==============================] - 720s 160ms/step - loss: 0.3303 - categorical_accuracy: 0.8532 - val_loss: 0.4224 - val_categorical_accuracy: 0.8089
# Epoch 5/5
# 4500/4500 [==============================] - 806s 179ms/step - loss: 0.2997 - categorical_accuracy: 0.8694 - val_loss: 0.4388 - val_categorical_accuracy: 0.8066
#               precision    recall  f1-score   support
#
#            0       0.81      0.73      0.77     22097
#            1       0.80      0.86      0.83     27903
#
#    micro avg       0.81      0.81      0.81     50000
#    macro avg       0.81      0.80      0.80     50000
# weighted avg       0.81      0.81      0.81     50000
#  samples avg       0.81      0.81      0.81     50000
#
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_72 (InputLayer)           (None, 50)           0
# __________________________________________________________________________________________________
# embedding_46 (Embedding)        (None, 50, 300)      6000000     input_72[0][0]
# __________________________________________________________________________________________________
# input_71 (InputLayer)           (None, 50, 1024)     0
# __________________________________________________________________________________________________
# concatenate_36 (Concatenate)    (None, 50, 1324)     0           embedding_46[0][0]
#                                                                  input_71[0][0]
# __________________________________________________________________________________________________
# bidirectional_20 (Bidirectional (None, 100)          550000      concatenate_36[0][0]
# __________________________________________________________________________________________________
# dense_52 (Dense)                (None, 2)            202         bidirectional_20[0][0]
# ==================================================================================================
# Total params: 6,550,202
# Trainable params: 6,550,202
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# Epoch 1/5
# 4500/4500 [==============================] - 750s 167ms/step - loss: 0.3595 - categorical_accuracy: 0.8377 - val_loss: 0.4211 - val_categorical_accuracy: 0.8074
# Epoch 4/5
# 4500/4500 [==============================] - 774s 172ms/step - loss: 0.2981 - categorical_accuracy: 0.8703 - val_loss: 0.4416 - val_categorical_accuracy: 0.8124
#               precision    recall  f1-score   support
#
#            0       0.84      0.72      0.77     22232
#            1       0.80      0.89      0.84     27768
#
#    micro avg       0.81      0.81      0.81     50000
#    macro avg       0.82      0.80      0.81     50000
# weighted avg       0.81      0.81      0.81     50000
#  samples avg       0.81      0.81      0.81     50000
#
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_74 (InputLayer)           (None, 50)           0
# __________________________________________________________________________________________________
# embedding_47 (Embedding)        (None, 50, 300)      6000000     input_74[0][0]
# __________________________________________________________________________________________________
# input_73 (InputLayer)           (None, 50, 1024)     0
# __________________________________________________________________________________________________
# concatenate_37 (Concatenate)    (None, 50, 1324)     0           embedding_47[0][0]
#                                                                  input_73[0][0]
# __________________________________________________________________________________________________
# bidirectional_21 (Bidirectional (None, 100)          550000      concatenate_37[0][0]
# __________________________________________________________________________________________________
# dense_53 (Dense)                (None, 2)            202         bidirectional_21[0][0]
# ==================================================================================================
# Total params: 6,550,202
# Trainable params: 6,550,202
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# Epoch 1/5
# 4500/4500 [==============================] - 769s 171ms/step - loss: 0.3603 - categorical_accuracy: 0.8367 - val_loss: 0.4075 - val_categorical_accuracy: 0.8115
# Epoch 4/5
# 4500/4500 [==============================] - 738s 164ms/step - loss: 0.2979 - categorical_accuracy: 0.8697 - val_loss: 0.4298 - val_categorical_accuracy: 0.8130
#               precision    recall  f1-score   support
#
#            0       0.83      0.72      0.77     21955
#            1       0.80      0.88      0.84     28045
#
#    micro avg       0.81      0.81      0.81     50000
#    macro avg       0.82      0.80      0.81     50000
# weighted avg       0.81      0.81      0.81     50000
#  samples avg       0.81      0.81      0.81     50000
#
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_76 (InputLayer)           (None, 50)           0
# __________________________________________________________________________________________________
# embedding_48 (Embedding)        (None, 50, 300)      6000000     input_76[0][0]
# __________________________________________________________________________________________________
# input_75 (InputLayer)           (None, 50, 1024)     0
# __________________________________________________________________________________________________
# concatenate_38 (Concatenate)    (None, 50, 1324)     0           embedding_48[0][0]
#                                                                  input_75[0][0]
# __________________________________________________________________________________________________
# bidirectional_22 (Bidirectional (None, 100)          550000      concatenate_38[0][0]
# __________________________________________________________________________________________________
# dense_54 (Dense)                (None, 2)            202         bidirectional_22[0][0]
# ==================================================================================================
# Total params: 6,550,202
# Trainable params: 6,550,202
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# Epoch 1/5
# 4500/4500 [==============================] - 811s 180ms/step - loss: 0.4632 - categorical_accuracy: 0.7753 - val_loss: 0.4313 - val_categorical_accuracy: 0.8009
# Epoch 2/5
# 4500/4500 [==============================] - 774s 172ms/step - loss: 0.3619 - categorical_accuracy: 0.8352 - val_loss: 0.4144 - val_categorical_accuracy: 0.8092
# Epoch 4/5
# 4500/4500 [==============================] - 702s 156ms/step - loss: 0.3306 - categorical_accuracy: 0.8531 - val_loss: 0.4180 - val_categorical_accuracy: 0.8114
# Epoch 5/5
# 4500/4500 [==============================] - 796s 177ms/step - loss: 0.2998 - categorical_accuracy: 0.8692 - val_loss: 0.4328 - val_categorical_accuracy: 0.8086
#               precision    recall  f1-score   support
#
#            0       0.81      0.74      0.77     22002
#            1       0.81      0.86      0.83     27998
#
#    micro avg       0.81      0.81      0.81     50000
#    macro avg       0.81      0.80      0.80     50000
# weighted avg       0.81      0.81      0.81     50000
#  samples avg       0.81      0.81      0.81     50000
#
# Precision: 0.8095 (+/- 0.0028)
# Recall: 0.8088 (+/- 0.0022)
# F1 Score: 0.8074 (+/- 0.0020)

# %%
print("Precision: %.4f (+/- %.4f)" % (np.mean(precisions), np.std(precisions)))
print("Recall: %.4f (+/- %.4f)" % (np.mean(recalls), np.std(recalls)))
print("F1 Score: %.4f (+/- %.4f)" % (np.mean(f1s), np.std(f1s)))
# Out:
# Precision: 0.8095 (+/- 0.0028)
# Recall: 0.8088 (+/- 0.0022)
# F1 Score: 0.8074 (+/- 0.0020)

# %%
print("Time: %.4f (+/- %.4f)" % (np.mean(times), np.std(times)))
# Out:
# Time: 3863.7398 (+/- 39.0300)
